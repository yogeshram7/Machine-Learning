# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
DT = pd.read_csv("study_hours.csv")
DT.head()
# Out:
#    Hours  Marks
# 0      5     30
# 1      8     32
# 2     10     35
# 3     12     37
# 4     15     40

# %%
#load dataset
x = DT.iloc[:,0:1].values
y = DT.iloc[:,1].values

# %%
#from linear Regression

from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(x,y)
y_lin = lin_reg.predict(x)

# %%
# polynomial Regression
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree = 2) # quardratic curve
x_poly = poly.fit_transform(x)

# %%
poly_reg = LinearRegression()
poly_reg.fit(x_poly,y)
y_poly = poly_reg.predict(x_poly)

# %%
# Plot Comparison 
plt.scatter(x,y)
plt.plot(x,y_lin)
plt.plot(x, y_poly)
plt.xlabel("Hours Studied")
plt.ylabel("Marks")
plt.title("Linear vs Polynomial Regression")
plt.show()

# %%
# -------- Compare R2 Scores --------
from sklearn.metrics import r2_score
print("Linear R2 Score:", r2_score(y, y_lin))
print("Polynomial R2 Score:", r2_score(y, y_poly))
# Out:
# Linear R2 Score: 0.998129908952438
# Polynomial R2 Score: 0.9991324524569327

# %%
import joblib 
joblib.dump(poly, "Polynomial_transform.pkl")
joblib.dump(poly_reg, "poly_regression.pkl")
print("success")
# Out:
# success
