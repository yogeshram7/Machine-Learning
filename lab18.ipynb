# %%
import pandas as pd
import numpy as np
data = {
"Hours": [1, 2, 3, np.nan, 5, 6, np.nan, 8],
"Marks": [10, 20, np.nan, 40, 50, np.nan, 70, 80]
}

df = pd.DataFrame(data)
print(df)

print(df.isnull())
print(df.isnull().sum())

df_mean = df.fillna(df.mean())
print(df_mean)

df_median = df.fillna(df.median())
print(df_median)

df_drop = df.dropna()
print(df_drop)

import matplotlib.pyplot as plt
plt.boxplot(df_median["Marks"])
plt.title("Boxplot for Marks")
plt.show()

Q1 = df_median["Marks"].quantile(0.25)
Q3 = df_median["Marks"].quantile(0.75)

IQR = Q3 - Q1

lower_limit = Q1 - 1.5 * IQR
upper_limit = Q3 + 1.5 * IQR

print("Lower Limit:", lower_limit)
print("Upper Limit:", upper_limit)

df_no_outliers = df_median[
(df_median["Marks"] >= lower_limit) &
(df_median["Marks"] <= upper_limit)
]

print(df_no_outliers)
# Out:
#    Hours  Marks
# 0    1.0   10.0
# 1    2.0   20.0
# 2    3.0    NaN
# 3    NaN   40.0
# 4    5.0   50.0
# 5    6.0    NaN
# 6    NaN   70.0
# 7    8.0   80.0
#    Hours  Marks
# 0  False  False
# 1  False  False
# 2  False   True
# 3   True  False
# 4  False  False
# 5  False   True
# 6   True  False
# 7  False  False
# Hours    2
# Marks    2
# dtype: int64
#       Hours  Marks
# 0  1.000000   10.0
# 1  2.000000   20.0
# 2  3.000000   45.0
# 3  4.166667   40.0
# 4  5.000000   50.0
# 5  6.000000   45.0
# 6  4.166667   70.0
# 7  8.000000   80.0
#    Hours  Marks
# 0    1.0   10.0
# 1    2.0   20.0
# 2    3.0   45.0
# 3    4.0   40.0
# 4    5.0   50.0
# 5    6.0   45.0
# 6    4.0   70.0
# 7    8.0   80.0
#    Hours  Marks
# 0    1.0   10.0
# 1    2.0   20.0
# 4    5.0   50.0
# 7    8.0   80.0
# Lower Limit: 5.0
# Upper Limit: 85.0
#    Hours  Marks
# 0    1.0   10.0
# 1    2.0   20.0
# 2    3.0   45.0
# 3    4.0   40.0
# 4    5.0   50.0
# 5    6.0   45.0
# 6    4.0   70.0
# ...
